# %% [markdown]
# # <span style="color:#2F80ED">Day 01 - Intro to Python</span>
# Welcome! This notebook shows first steps with Python syntax.
#
# ## <span style="color:#27AE60">Goals</span>
# - <span style="color:#9B51E0">Run your first program</span>
# - <span style="color:#F2994A">Practice variable names and case sensitivity</span>
# - <span style="color:#EB5757">Learn why keywords and built-ins should not be reused</span>
# - <span style="color:#2D9CDB">See a simple conditional</span>

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## <span style="color:#F2994A">Variables and names</span>
# Python is case-sensitive. Each name below is different and stores its own value.

# %%
name= 'noha'

Name= 'Ahmed'

nAme = 'Omar'

# %% [markdown]
# ## <span style="color:#EB5757">Reserved keywords</span>
# Some words are part of the language (like `if`) and cannot be used as variable names.

# %%
if = 10
# Out:
#   Cell In[4], line 1
#     if = 10
#        ^
# SyntaxError: invalid syntax

# %%
print(name)
# Out:
# noha

# %% [markdown]
# ## <span style="color:#9B51E0">Built-in functions</span>
# Names like `print` are built in. Reusing them hides the function and can break later code.

# %%
print = 10

# %%
print(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(name)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ## <span style="color:#2D9CDB">Simple conditional</span>
# A basic `if` checks a condition and runs an indented block when it is true.

# %%
num = 10
if num == 10:
    print("found")
