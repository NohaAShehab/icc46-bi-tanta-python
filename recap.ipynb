# %%
iti = "information technology institute"

for anyvalue in iti:
    print(f"anyvalue = {anyvalue}")
# Out:
# anyvalue = i
# anyvalue = n
# anyvalue = f
# anyvalue = o
# anyvalue = r
# anyvalue = m
# anyvalue = a
# anyvalue = t
# anyvalue = i
# anyvalue = o
# anyvalue = n
# anyvalue =
# anyvalue = t
# anyvalue = e
# anyvalue = c
# anyvalue = h
# anyvalue = n
# anyvalue = o
# anyvalue = l
# anyvalue = o
# anyvalue = g
# anyvalue = y
# anyvalue =
# anyvalue = i
# anyvalue = n
# anyvalue = s
# anyvalue = t
# anyvalue = i
# anyvalue = t
# anyvalue = u
# anyvalue = t
# anyvalue = e

# %%
anystring = "information technology institute"

counter = 0
for char in anystring:
    if char in "aeiou":
        counter += 1

print(counter)
# Out:
# 12
