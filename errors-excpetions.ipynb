# %%
from prompt_toolkit import pep440
print("hello world"
# Out:
#   Cell In[1], line 1
#     print("hello world"
#                        ^
# _IncompleteInputError: incomplete input

# %%
if:
    print("hi")
# Out:
#   Cell In[2], line 1
#     if:
#       ^
# SyntaxError: invalid syntax

# %%
# logical error ?
def sum_num(num1:int, num2:int) -> int:
    if isinstance(num1,int) and isinstance(num2,int):
        return num1 * num2
    return None

res1 = sum_num(2,2)
res2 = sum_num(3,4)
print(res1, res2)

# developer ?? define test cases, unit testing script
# Out:
# 4 12

# %% [markdown]
# # Runtime errors (Exception)

# %%
print(username)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(username)
#
# NameError: name 'username' is not defined

# %%
res = 5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 res = 5/0
#
# ZeroDivisionError: division by zero

# %%
num = int(input("Please enter a number: "))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 num = int(input("Please enter a number: "))
#
# ValueError: invalid literal for int() with base 10: 'ewr'

# %%
"""
    any code may cause issues , we will wrapp it in try:except block

"""

try:
    num = int(input("Please enter a number: "))
    print(f"num is {num}")
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'nummm'

# %%
try:
    num = int(input("Please enter a number: "))
    print(f"num is {num}")
except Exception as e:
    print(e)
# Out:
# num is 55

# %%
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))

    res = num1/num2
    print(f"res = {res}")
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))

    res = num1/num2
    print(f"res = {res}")
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'etette'

# %%
# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))

    res = num1/num2
    print(f"res = {res}")
except Exception as e:
    print(e)
    # handling exception
    res = math.inf
    print(f"res = {res}")
# Out:
# division by zero
# res = inf

# %%
# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))

    res = num1/num2
    print(f"res = {res}")
except Exception as e:
    print(e)
    # handling exception
    res = math.inf
    print(f"res = {res}")
# Out:
# invalid literal for int() with base 10: 'qweqw'
# res = inf

# %%
# define actions based on issues

# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))

    res = num1/num2
    print(f"res = {res}")
except ZeroDivisionError as e:
    print(e)
    res = math.inf
    print(res)
except ValueError as ve:
    print(ve)
    print("--- Num1, num2 must be numeric values ")
    res = False
    print(res)
# Out:
# division by zero
# inf

# %%
# define actions based on issues

# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))

    res = num1/num2
    print(f"res = {res}")
except ZeroDivisionError as e:
    print(e)
    res = math.inf
    print(res)
except ValueError as ve:
    print(ve)
    print("--- Num1, num2 must be numeric values ")
    res = False
    print(res)
# Out:
# invalid literal for int() with base 10: 'iik'
# --- Num1, num2 must be numeric values
# False

# %%
def ask_for_int(message="Please enter an integer: "):
    while True:
        try:
            num = int(input(message))
            return num
        except ValueError as e:
            print("Please enter an integer")

ask_for_int()
# Out:
# Please enter an integer
# Please enter an integer
# 123132

# %%
# define actions based on issues

# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))

    res = num1/num2
    print(f"res = {res}")
except ZeroDivisionError as e:
    print(e)
    res = math.inf
    print(res)
except ValueError as ve:
    print(ve)
    print("--- Num1, num2 must be numeric values ")
    res = False
    print(res)
except Exception as e:
    # this is the default for any exception...
    print(e)
    print("--- Problem happened ---")

# %%
# define actions based on issues

# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))
    res = num1/num2
    print(f"res = {res}")
except Exception as e:
    if isinstance(e, ZeroDivisionError):
        res = math.inf
    else:
        res = False
    print(res)
else:
    print("--- content of this block will be executed only if there are no exceptions ")
# Out:
# res = 4.888888888888889
# --- content of this block will be executed only if there are no exceptions

# %% [markdown]
# # else block

# %%
# define actions based on issues

# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))
    res = num1/num2
except Exception as e:
    if isinstance(e, ZeroDivisionError):
        res = math.inf
    else:
        res = False
    print(res)
else:
    print(f"res = {res}")
    print("--- content of this block will be executed only if there are no exceptions ")

# %% [markdown]
# # finally

# %%
# define actions based on issues

# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))
    res = num1/num2
except Exception as e:
    if isinstance(e, ZeroDivisionError):
        res = math.inf
    else:
        res = False
    print(res)
else:
    print(f"res = {res}")
    print("--- content of this block will be executed only if there are no exceptions ")
finally:
    print("--- content of this block will be executed always")
# Out:
# False
# --- content of this block will be executed always

# %%
# define actions based on issues

# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))
    res = num1/num2
except Exception as e:
    if isinstance(e, ZeroDivisionError):
        res = math.inf
    else:
        res = False
    print(res)
else:
    print(f"res = {res}")
    print("--- content of this block will be executed only if there are no exceptions ")
finally:
    print("--- content of this block will be executed always")
# Out:
# res = 7.666666666666667
# --- content of this block will be executed only if there are no exceptions
# --- content of this block will be executed always

# %%
# define actions based on issues

# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))
    res = num1/num2
except Exception as e:
    if isinstance(e, ZeroDivisionError):
        res = math.inf
    else:
        res = False
    print(res)
else:
    print(f"res = {res}")
    print("--- content of this block will be executed only if there are no exceptions ")
finally:
    print("--- content of this block will be executed always")

print("******************************************")
# Out:
# False
# --- content of this block will be executed always
# ******************************************

# %%
# define actions based on issues

# you handle the exception
import  math
try:
    num1 = int(input("Please enter a number: "))
    num2 = int(input("Please enter a number: "))
    res = num1/num2
except Exception as e:
    if isinstance(e, ZeroDivisionError):
        res = math.inf
    else:
        res = False
    print(res)
else:
    print(f"res = {res}")
    print("--- content of this block will be executed only if there are no exceptions ")
finally:
    print("--- content of this block will be executed always")

print("******************************************")
# Out:
# inf
# --- content of this block will be executed always
# ******************************************

# %%
def ask_for_int(message='please enter an integer: '):
    try:
        num = int(input(message))
    except ValueError as ve:
        print("Not valid input")
        return  False
    else:
        print(f"res = {num}")
        return num
    finally:
        "inside the function block, execution of finally preceeds the return value"
        print('process executed successfully')
    print("*****************************")

res = ask_for_int()
print(res)
# Out:
# res = 344
# process executed successfully
# 344

# %%
def register():
    try:
        age = int(input("Please enter your age: "))
    except Exception as e:
        print(e)
        print("Age must be an integer")
        age= 0
        return age
    else:
        print(f"Age {age}")
        return age
    finally:
        print("Hint, age must be an integer, Thank you for your help")

register()
# Out:
# Age 234234
# Hint, age must be an integer, Thank you for your help
# 234234

# %%
def register():
    try:
        age = int(input("Please enter your age: "))
    except Exception as e:
        print(e)
        print("Age must be an integer")
        age= 0
        return age
    else:
        print(f"Age {age}")
        return age
    finally:
        print("Hint, age must be an integer, Thank you for your help")

register()
# Out:
# invalid literal for int() with base 10: 'wqrr'
# Age must be an integer
# Hint, age must be an integer, Thank you for your help
# 0

# %% [markdown]
# # Raise Exception

# %%
def div_nums():
    num1 = input("please enter a number: ")
    num2 = input("please enter a number: ")
    if num1.isdigit() and num2.isdigit():
        print(f'num1 = {num1}, num2 = {num2}')
        res = int(num1) / int(num2)
        return res

res= div_nums()
print(res)
# Out:
# None

# %%
def div_nums():
    num1 = input("please enter a number: ")
    num2 = input("please enter a number: ")
    if num1.isdigit() and num2.isdigit():
        print(f'num1 = {num1}, num2 = {num2}')
        res = int(num1) / int(num2)
        return res

res= div_nums()
print(res)
# Out:
# num1 = 23, num2 = 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[37], line 9
#       6         res = int(num1) / int(num2)
#       7         return res
# ----> 9 res= div_nums()
#      10 print(res)
#
# Cell In[37], line 6, in div_nums()
#       4 if num1.isdigit() and num2.isdigit():
#       5     print(f'num1 = {num1}, num2 = {num2}')
# ----> 6     res = int(num1) / int(num2)
#       7     return res
#
# ZeroDivisionError: division by zero

# %%
def div_nums():
    num1 = input("please enter a number: ")
    num2 = input("please enter a number: ")
    if num2=="0":
        raise ZeroDivisionError("division by zero")
    if num1.isdigit() and num2.isdigit():
        print(f'num1 = {num1}, num2 = {num2}')
        res = int(num1) / int(num2)
        return res

res= div_nums()
print(res)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[38], line 11
#       8         res = int(num1) / int(num2)
#       9         return res
# ---> 11 res= div_nums()
#      12 print(res)
#
# Cell In[38], line 5, in div_nums()
#       3 num2 = input("please enter a number: ")
#       4 if num2=="0":
# ----> 5     raise ZeroDivisionError("division by zero")
#       6 if num1.isdigit() and num2.isdigit():
#       7     print(f'num1 = {num1}, num2 = {num2}')
#
# ZeroDivisionError: division by zero
